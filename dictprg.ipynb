# %%
#dictionary 
#it is the unordered collection of key and value elements

# %%
d={'a':100, 'b': 200}

# %%
d
# Out:
# {'a': 100, 'b': 200}

# %%
#features of dictionary
#it is mutable

# %%
d['c']=300

# %%
d
# Out:
# {'a': 100, 'b': 200, 'c': 300}

# %%
d['c']=400

# %%
d
# Out:
# {'a': 100, 'b': 200, 'c': 400}

# %%
d1={'name':'Prajwal', 'num':45, 'result': 'Pass', 'num':47}

# %%
d1
# Out:
# {'name': 'Prajwal', 'num': 47, 'result': 'Pass'}

# %%
#functions in dictionary
#get(), popitem()

# %%
d1.get('name','hello')
# Out:
# 'Prajwal'

# %%
d1.get('place','hello')
# Out:
# 'hello'

# %%
d1.popitem()
# Out:
# ('result', 'Pass')

# %%
d1
# Out:
# {'name': 'Prajwal', 'num': 47}

# %%
d1.keys()
# Out:
# dict_keys(['name', 'num'])

# %%
d1.values()
# Out:
# dict_values(['Prajwal', 47])

# %%
d1.items()
# Out:
# dict_items([('name', 'Prajwal'), ('num', 47)])

# %%
#setdefault

# %%
d1
# Out:
# {'name': 'Prajwal', 'num': 47}

# %%
d1.setdefault('name', 'xyz')
# Out:
# 'Prajwal'

# %%
d1.setdefault('email', 'prajwal@gmail.com')
# Out:
# 'prajwal@gmail.com'

# %%
d1
# Out:
# {'name': 'Prajwal', 'num': 47, 'email': 'prajwal@gmail.com'}

# %%
#fromkeys

# %%
players=['kl rahul', 'ms dhoni', 'virat kohli']

# %%
p={}.fromkeys(players)

# %%
p
# Out:
# {'kl rahul': None, 'ms dhoni': None, 'virat kohli': None}
