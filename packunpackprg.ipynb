# %%
std=['prajwal',100,20,30,40]

# %%
name,roll_no,*marks=std
name
# Out:
# 'prajwal'

# %%
marks
# Out:
# [20, 30, 40]

# %%
roll_no
# Out:
# 100

# %%
n=int(input())
ist=[10,20,30,40,50]
for i in range(n -1,-1,-1):
    print(i)
