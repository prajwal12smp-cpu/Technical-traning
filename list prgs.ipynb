# %%
n = [10,5,3, 'Hello',5.3]

# %%
#list is mutable

# %%
n[1]=100

# %%
n
# Out:
# [10, 100, 3, 'Hello', 5.3]

# %%
del n[3]

# %%
n
# Out:
# [10, 100, 3, 5.3]

# %%
#list does have duplicates

# %%
n1=[10,5,10]

# %%
n1
# Out:
# [10, 5, 10]

# %%
#list has -ve and +ve indexes

# %%
n1[-1]
# Out:
# 10

# %%
n1[-2]
# Out:
# 5

# %%
#fuctions on list
#list has inbuilt functions
#append #remove # insert

# %%
num=[10,20,30]

# %%
num.append(500)

# %%
num
# Out:
# [10, 20, 30, 500, 500]

# %%
num.insert(2,1000)

# %%
num
# Out:
# [10, 20, 1000, 30, 500, 500]

# %%
num.insert(-3,200)

# %%
num
# Out:
# [10, 20, 1000, 200, 200, 30, 500, 500]

# %%
#pop, pop(item), sort

# %%
numai=[15,25,35,45,55]

# %%
numai.pop(1)
# Out:
# 25

# %%
numai
# Out:
# [15, 35, 45, 55]

# %%
numai.pop()
# Out:
# 55

# %%
numai.pop(9)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 numai.pop(9)
#
# IndexError: pop index out of range

# %%
#index,count, sort

# %%
numai1=[11,22,11,33,44]

# %%
numai1.index(11)
# Out:
# 0

# %%
numai1.count(22)
# Out:
# 1

# %%
numai1.count(11)
# Out:
# 2

# %%
numsort=[10,-1,3,7,-3,9]

# %%
numsort.sort()

# %%
numsort
# Out:
# [-3, -1, 3, 7, 9, 10]

# %%
numsort.sort(reverse=True)

# %%
numsort
# Out:
# [10, 9, 7, 3, -1, -3]

# %%
numreverse=[2,4,6,8,10,12]

# %%
numreverse.reverse()

# %%
numreverse
# Out:
# [12, 10, 8, 6, 4, 2]
