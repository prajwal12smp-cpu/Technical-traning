# %%
#set 
#it is unordered collection of unique of elements

# %%
s1={1,2,3,4,1}

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s2={2,4,7,8,9}

# %%
s2
# Out:
# {2, 4, 7, 8, 9}

# %%
names={'c','a','b','d'}
names
# Out:
# {'a', 'b', 'c', 'd'}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 7, 8, 9}

# %%
s1.intersection(s2)
# Out:
# {2, 4}

# %%
s1.difference(s2)
# Out:
# {1, 3}

# %%
ft={1,4,6,7,8}
ct={4,9,11,7,3}

# %%
ft.intersection(ct)
# Out:
# {4, 7}

# %%
ft.union(ct)
# Out:
# {1, 3, 4, 6, 7, 8, 9, 11}

# %%
#functions of sets

# %%
s1.add(100)

# %%
s1
# Out:
# {1, 2, 3, 4, 100}

# %%
s1.discard(4)

# %%
s1
# Out:
# {1, 2, 3, 100}

# %%
s1.discard(7)

# %%
s1
# Out:
# {1, 2, 3, 100}

# %%
s1
# Out:
# {1, 2, 3, 100}

# %%
ist=[1,4,7,1,4,8]
i1=set(ist)

# %%
i1
# Out:
# {1, 4, 7, 8}
