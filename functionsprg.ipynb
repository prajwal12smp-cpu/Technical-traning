# %%
def  f1(l1):
    return sum(l1),max(l1)

# %%
l=[10,20,30,40,50]
n1,n2=f1(l)

# %%
print(n1,n2)
# Out:
# 150 50

# %%
def f2(a,b,c=0):
    return a++b+c

# %%
print(f2(10,20,30))
# Out:
# 60

# %%
print(f2(10,20))
# Out:
# 30

# %%
# *kargs, **kwargs

# %%
#*kargs
def d(*a):
    print(a)

# %%
d()
# Out:
# ()

# %%
d(10)
# Out:
# (10,)

# %%
d(20,30)
# Out:
# (20, 30)

# %%
d(20+30)
# Out:
# (50,)

# %%
#**kwargs
def d3(**a):
    print(a)

# %%
d3(name='prajwal',num=10)
# Out:
# {'name': 'prajwal', 'num': 10}

# %%
#lambda function
s=lambda a,b,c:a+b+c

# %%
type(s)
# Out:
# function

# %%
s(10,20,40)
# Out:
# 70

# %%
l1=[10,20,30,40]
nl1=map(lambda x:x+10,l1)

# %%
print(list(nl1))
# Out:
# [20, 30, 40, 50]

# %%
b=[20,30,40,50,60]
n=map(lambda x:x+3,b)
print(list(n))
# Out:
# [23, 33, 43, 53, 63]

# %%
num = [50,40,30,20,10,35,17]

# %%
nnum = filter(lambda x:x%2==0,num)

# %%
print(list(nnum))
# Out:
# [50, 40, 30, 20, 10]

# %%
from functools import reduce

# %%
a=[10,20,40,50]

# %%
total = reduce(lambda x,y:x+y,a)

# %%
print(total)
# Out:
# 120

# %%
#Encapsulation -----> data hiding,data+function, in python we represent symbol (__)
